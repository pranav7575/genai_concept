# %%
# Tokenization using NLTK library NLP
# !pip install nltk
# Out:
# ...
# [notice] A new release of pip is available: 23.2.1 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import nltk
nltk.data.path.append(r"C:\Users\prana\AppData\Roaming\nltk_data")

# Download all NLTK data if not already present
nltk.download('punkt')
nltk.download('punkt_tab')
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\prana\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     C:\Users\prana\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\prana\AppData\Roaming\nltk_data...
# True

# %%
corpus = """
My Name Is Pranav jadhav. I am learning Natural Language Processing using NLTK library in Python. currently, I am working on text tokenization. Tokenization is the process of breaking down text into smaller units called tokens, which can be words, phrases, or sentences. It is a fundamental step in NLP tasks such as text analysis, sentiment analysis, and machine learning.
"""

# %%
from nltk.tokenize import sent_tokenize, word_tokenize,wordpunct_tokenize

# %%
document_sentences = sent_tokenize(corpus)
print(document_sentences)  # Display the tokenized sentences
# Out:
# ['\nMy Name Is Pranav jadhav.', 'I am learning Natural Language Processing using NLTK library in Python.', 'currently, I am working on text tokenization.', 'Tokenization is the process of breaking down text into smaller units called tokens, which can be words, phrases, or sentences.', 'It is a fundamental step in NLP tasks such as text analysis, sentiment analysis, and machine learning.']

# %%
for sentence in document_sentences:
    print(sentence)
# Out:
# My Name Is Pranav jadhav.
# I am learning Natural Language Processing using NLTK library in Python.
# currently, I am working on text tokenization.
# Tokenization is the process of breaking down text into smaller units called tokens, which can be words, phrases, or sentences.
# It is a fundamental step in NLP tasks such as text analysis, sentiment analysis, and machine learning.

# %%
document=word_tokenize(corpus)

# %%
for word in document:
    print(word)  # Display the tokenized words
# Out:
# My
# Name
# Is
# Pranav
# jadhav
# .
# I
# am
# learning
# Natural
# Language
# Processing
# using
# NLTK
# library
# in
# Python
# .
# currently
# ,
# I
# am
# working
# on
# text
# tokenization
# .
# Tokenization
# is
# the
# process
# of
# breaking
# down
# text
# into
# smaller
# units
# called
# tokens
# ,
# which
# can
# be
# words
# ,
# phrases
# ,
# or
# sentences
# .
# It
# is
# a
# fundamental
# step
# in
# NLP
# tasks
# such
# as
# text
# analysis
# ,
# sentiment
# analysis
# ,
# and
# machine
# learning
# .

# %%
word_punct_tokens = wordpunct_tokenize(corpus)
print(word_punct_tokens)  # Display the word punctuation tokens
# Out:
# ['My', 'Name', 'Is', 'Pranav', 'jadhav', '.', 'I', 'am', 'learning', 'Natural', 'Language', 'Processing', 'using', 'NLTK', 'library', 'in', 'Python', '.', 'currently', ',', 'I', 'am', 'working', 'on', 'text', 'tokenization', '.', 'Tokenization', 'is', 'the', 'process', 'of', 'breaking', 'down', 'text', 'into', 'smaller', 'units', 'called', 'tokens', ',', 'which', 'can', 'be', 'words', ',', 'phrases', ',', 'or', 'sentences', '.', 'It', 'is', 'a', 'fundamental', 'step', 'in', 'NLP', 'tasks', 'such', 'as', 'text', 'analysis', ',', 'sentiment', 'analysis', ',', 'and', 'machine', 'learning', '.']

# %%
from nltk.tokenize import TreebankWordTokenizer
tokenizer = TreebankWordTokenizer()

# %%
TreebankWordTokenizer_tokens=tokenizer.tokenize(corpus)
print(TreebankWordTokenizer_tokens)  # Display the Treebank word tokens
# Out:
# ['My', 'Name', 'Is', 'Pranav', 'jadhav.', 'I', 'am', 'learning', 'Natural', 'Language', 'Processing', 'using', 'NLTK', 'library', 'in', 'Python.', 'currently', ',', 'I', 'am', 'working', 'on', 'text', 'tokenization.', 'Tokenization', 'is', 'the', 'process', 'of', 'breaking', 'down', 'text', 'into', 'smaller', 'units', 'called', 'tokens', ',', 'which', 'can', 'be', 'words', ',', 'phrases', ',', 'or', 'sentences.', 'It', 'is', 'a', 'fundamental', 'step', 'in', 'NLP', 'tasks', 'such', 'as', 'text', 'analysis', ',', 'sentiment', 'analysis', ',', 'and', 'machine', 'learning', '.']
